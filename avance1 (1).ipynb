# %%
# %ls base
# Out:
# Water_Consumption_in_the_City_of_New_York.xlsx

# %%
import pandas as pd
import numpy as np

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 164 kB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 4.9 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('base/Water_Consumption_in_the_City_of_New_York.xlsx',
                   engine = 'openpyxl',
                   #sheet_name ='casos_positivos',
                   #skiprows = range(20),
                   #skipfooter = 2
                  )
df.head(20)
# Out:
#     Year  New York City Population  NYC Consumption(Million gallons per day)  \
# 0   1979                 7102100.0                                    1512.0
# 1   1980                 7071639.0                                    1506.0
# 2   1981                 7089241.0                                    1309.0
# 3   1982                 7109105.0                                    1382.0
# 4   1983                 7181224.0                                    1424.0
# 5   1984                 7234514.0                                    1465.0
# 6   1985                 7274054.0                                    1326.0
# 7   1986                 7319246.0                                    1351.0
# 8   1987                 7342476.0                                    1447.0
# 9   1988                 7353719.0                                    1484.0
# 10  1989                 7344175.0                                    1402.0
# ...

# %% [markdown]
# The dataset that is being analyzed, was obtained form the CDMX state goverment.

# %%
column = df['NYC Consumption(Million gallons per day)']
print(column.max())
# Out:
# 1512.0

# %%
df.head(1)
# Out:
#    Year  New York City Population  NYC Consumption(Million gallons per day)  \
# 0  1979                 7102100.0                                    1512.0
#
#    Per Capita(Gallons per person per day)
# 0                                     213

# %%
df2 = df[['New York City Population','NYC Consumption(Million gallons per day)']
]

# %%
df2.head()
# Out:
#    New York City Population  NYC Consumption(Million gallons per day)
# 0                 7102100.0                                    1512.0
# 1                 7071639.0                                    1506.0
# 2                 7089241.0                                    1309.0
# 3                 7109105.0                                    1382.0
# 4                 7181224.0                                    1424.0

# %%
df2.plot(x='New York City Population',y='NYC Consumption(Million gallons per day)',kind='line')
